# %% [markdown]
# # Fermentation data import and export

# %% [markdown]
# ## 1. Imports and directory definitions

# %%
import pandas as pd # pandas for tabular data manipulation
import numpy as np  # numpy for numerical operations
import glob
import os
from pandas import ExcelWriter
import openpyxl

data_folder = '../../../data/'
fieldlist_path = '../fieldlist/fieldlist_v1.xlsx'
od_cal_file = '../2021-10-04_OD_calibration_file.xlsx'

# %% [markdown]
# ## 2. Experient name definition

# %%
experiment = 'DDB_PD_045_AMBR'

# %% [markdown]
# ## 3. Import data

# %% [markdown]
# ### 3.1 Main cultures metadata

# %%
# get the path to experiment in the LIMS file folder
experiment_file = data_folder+'LIMS_data/'+experiment+'_LIMS.xlsx'
# import the data from the main culture sheet and drop any column that has only NaNs
meta_data = pd.read_excel(experiment_file, sheet_name='main culture').dropna(how='all', axis=1)
    
# cultures.index = range(0,len(cultures.index)) # updating the index of the dataframe
meta_data.rename(columns={'Sample ID': 'Parent Culture'}, inplace=True)
meta_data.sort_values('Reactor/Plate/Flask Number',inplace=True)
meta_data = meta_data.reset_index().drop('index',axis=1)
meta_data
# Out:
#                           Parent Culture Base Medium  \
# 0   DDB_PD_045_AMBR_SDT169-001_R01_Main_  DDB_BM_002
# 1   DDB_PD_045_AMBR_SDT169-001_R02_Main_  DDB_BM_002
# 2   DDB_PD_045_AMBR_SDT171-001_R03_Main_  DDB_BM_002
# 3   DDB_PD_045_AMBR_SDT171-001_R04_Main_  DDB_BM_002
# 4   DDB_PD_045_AMBR_SDT172-001_R05_Main_  DDB_BM_002
# 5   DDB_PD_045_AMBR_SDT172-001_R06_Main_  DDB_BM_002
# 6   DDB_PD_045_AMBR_SDT173-001_R07_Main_  DDB_BM_002
# 7   DDB_PD_045_AMBR_SDT173-001_R08_Main_  DDB_BM_002
# 8   DDB_PD_045_AMBR_SDT174-001_R09_Main_  DDB_BM_002
# 9   DDB_PD_045_AMBR_SDT174-001_R10_Main_  DDB_BM_002
# 10  DDB_PD_045_AMBR_SDT175-001_R11_Main_  DDB_BM_002
# 11  DDB_PD_045_AMBR_SDT175-001_R12_Main_  DDB_BM_002
# 12  DDB_PD_045_AMBR_SDT176-001_R13_Main_  DDB_BM_002
# 13  DDB_PD_045_AMBR_SDT176-001_R14_Main_  DDB_BM_002
# 14  DDB_PD_045_AMBR_SDT177-001_R15_Main_  DDB_BM_002
# 15  DDB_PD_045_AMBR_SDT177-001_R16_Main_  DDB_BM_002
# 16  DDB_PD_045_AMBR_SDT178-001_R17_Main_  DDB_BM_002
# 17  DDB_PD_045_AMBR_SDT178-001_R18_Main_  DDB_BM_002
# 18  DDB_PD_045_AMBR_SDT179-001_R19_Main_  DDB_BM_002
# 19  DDB_PD_045_AMBR_SDT179-001_R20_Main_  DDB_BM_002
# 20  DDB_PD_045_AMBR_SDT180-001_R21_Main_  DDB_BM_002
# 21  DDB_PD_045_AMBR_SDT180-001_R22_Main_  DDB_BM_002
# 22  DDB_PD_045_AMBR_SDT189-001_R23_Main_  DDB_BM_002
# 23  DDB_PD_045_AMBR_SDT189-001_R24_Main_  DDB_BM_002
#
#    Container ID (calculated) Container Type Control? Culture Type  \
# 0                        R01       AMBR 250       No         Main
# 1                        R02       AMBR 250       No         Main
# 2                        R03       AMBR 250       No         Main
# 3                        R04       AMBR 250       No         Main
# 4                        R05       AMBR 250       No         Main
# 5                        R06       AMBR 250       No         Main
# 6                        R07       AMBR 250       No         Main
# 7                        R08       AMBR 250       No         Main
# 8                        R09       AMBR 250       No         Main
# 9                        R10       AMBR 250       No         Main
# 10                       R11       AMBR 250       No         Main
# 11                       R12       AMBR 250       No         Main
# 12                       R13       AMBR 250       No         Main
# 13                       R14       AMBR 250       No         Main
# 14                       R15       AMBR 250       No         Main
# 15                       R16       AMBR 250       No         Main
# 16                       R17       AMBR 250       No         Main
# 17                       R18       AMBR 250       No         Main
# 18                       R19       AMBR 250       No         Main
# 19                       R20       AMBR 250       No         Main
# 20                       R21       AMBR 250       No         Main
# 21                       R22       AMBR 250       No         Main
# 22                       R23       AMBR 250       No         Main
# 23                       R24       AMBR 250       No         Main
#
#          Experiment Experiment Annotation  growth_rate Feed Medium #1  ...  \
# 0   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 1   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 2   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 3   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 4   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 5   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 6   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 7   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 8   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 9   DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 10  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 11  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 12  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 13  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 14  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 15  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 16  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 17  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 18  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 19  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 20  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 21  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 22  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
# 23  DDB_PD_045_AMBR             DDB TF KO         0.11     DDB_FM_002  ...
#
#    pH Setpoint  pH Control Base Solution DO Control Setpoint (%)  \
# 0          6.5    Ammonium hydroxide 15%                      40
# 1          6.5    Ammonium hydroxide 15%                      40
# 2          6.5    Ammonium hydroxide 15%                      40
# 3          6.5    Ammonium hydroxide 15%                      40
# 4          6.5    Ammonium hydroxide 15%                      40
# 5          6.5    Ammonium hydroxide 15%                      40
# 6          6.5    Ammonium hydroxide 15%                      40
# 7          6.5    Ammonium hydroxide 15%                      40
# 8          6.5    Ammonium hydroxide 15%                      40
# 9          6.5    Ammonium hydroxide 15%                      40
# 10         6.5    Ammonium hydroxide 15%                      40
# 11         6.5    Ammonium hydroxide 15%                      40
# 12         6.5    Ammonium hydroxide 15%                      40
# 13         6.5    Ammonium hydroxide 15%                      40
# 14         6.5    Ammonium hydroxide 15%                      40
# 15         6.5    Ammonium hydroxide 15%                      40
# 16         6.5    Ammonium hydroxide 15%                      40
# 17         6.5    Ammonium hydroxide 15%                      40
# 18         6.5    Ammonium hydroxide 15%                      40
# 19         6.5    Ammonium hydroxide 15%                      40
# 20         6.5    Ammonium hydroxide 15%                      40
# 21         6.5    Ammonium hydroxide 15%                      40
# 22         6.5    Ammonium hydroxide 15%                      40
# 23         6.5    Ammonium hydroxide 15%                      40
#
#    DO Control Cascade Level 1 DO Control Cascade Level 2  \
# 0                    Stirring                   Aeration
# 1                    Stirring                   Aeration
# 2                    Stirring                   Aeration
# 3                    Stirring                   Aeration
# 4                    Stirring                   Aeration
# 5                    Stirring                   Aeration
# 6                    Stirring                   Aeration
# 7                    Stirring                   Aeration
# 8                    Stirring                   Aeration
# 9                    Stirring                   Aeration
# 10                   Stirring                   Aeration
# 11                   Stirring                   Aeration
# 12                   Stirring                   Aeration
# 13                   Stirring                   Aeration
# 14                   Stirring                   Aeration
# 15                   Stirring                   Aeration
# 16                   Stirring                   Aeration
# 17                   Stirring                   Aeration
# 18                   Stirring                   Aeration
# 19                   Stirring                   Aeration
# 20                   Stirring                   Aeration
# 21                   Stirring                   Aeration
# 22                   Stirring                   Aeration
# 23                   Stirring                   Aeration
#
#     Minimum Aeration (slpm) Maximum Aeration (slpm)  \
# 0                       0.1                    0.23
# 1                       0.1                    0.23
# 2                       0.1                    0.23
# 3                       0.1                    0.23
# 4                       0.1                    0.23
# 5                       0.1                    0.23
# 6                       0.1                    0.23
# 7                       0.1                    0.23
# 8                       0.1                    0.23
# 9                       0.1                    0.23
# 10                      0.1                    0.23
# 11                      0.1                    0.23
# 12                      0.1                    0.23
# 13                      0.1                    0.23
# 14                      0.1                    0.23
# 15                      0.1                    0.23
# 16                      0.1                    0.23
# 17                      0.1                    0.23
# 18                      0.1                    0.23
# 19                      0.1                    0.23
# 20                      0.1                    0.23
# 21                      0.1                    0.23
# 22                      0.1                    0.23
# 23                      0.1                    0.23
#
#     Minimum Stirring or Shaking Speed (rpm)  \
# 0                                      1000
# 1                                      1000
# 2                                      1000
# 3                                      1000
# 4                                      1000
# 5                                      1000
# 6                                      1000
# 7                                      1000
# 8                                      1000
# 9                                      1000
# 10                                     1000
# 11                                     1000
# 12                                     1000
# 13                                     1000
# 14                                     1000
# 15                                     1000
# 16                                     1000
# 17                                     1000
# 18                                     1000
# 19                                     1000
# 20                                     1000
# 21                                     1000
# 22                                     1000
# 23                                     1000
#
#     Maximum Stirring or Shaking Speed (rpm) Aeration Gas Type
# 0                                      4000               Air
# 1                                      4000               Air
# 2                                      4000               Air
# 3                                      4000               Air
# 4                                      4000               Air
# 5                                      4000               Air
# 6                                      4000               Air
# 7                                      4000               Air
# 8                                      4000               Air
# 9                                      4000               Air
# 10                                     4000               Air
# 11                                     4000               Air
# 12                                     4000               Air
# 13                                     4000               Air
# 14                                     4000               Air
# 15                                     4000               Air
# 16                                     4000               Air
# 17                                     4000               Air
# 18                                     4000               Air
# 19                                     4000               Air
# 20                                     4000               Air
# 21                                     4000               Air
# 22                                     4000               Air
# 23                                     4000               Air
#
# [24 rows x 30 columns]

# %% [markdown]
# ### 3.1 Online data

# %%
online_data_dir = 'online_data_interpolated/'
csv_prefix = '_online_stacked_2m.csv'

# %%
# import fieldlist
fieldlist = pd.read_excel(fieldlist_path)
# initialize an empty DataFrame with columns from the variables specified in the fieldlist
online_data = pd.DataFrame(columns=list(fieldlist.new_variable_name))

# %%
ambr_df = pd.read_csv(data_folder+ online_data_dir + str(experiment) + csv_prefix)

for column in list(online_data.columns): # iterate over the columns of the temporary dataframe. The columns are the variable names of the online data.
    # match the column name (new_variable_name) to the name given by ambr250. Then assign the ambr250 online data to the matching column in the temp_df
    online_data[column] = ambr_df[fieldlist[fieldlist.new_variable_name == column].AMBR_name.iloc[0]]

# adding a column with the experiment name
online_data['Experiment'] = experiment

# Converting the bioreactor naming format in the temporary ambr df
for i in range(1,10):
    ambr_df['Batch ID'] = ambr_df['Batch ID'].replace('Bioreactor '+str(i),'R0'+str(i))
for i in range(10,25):
    ambr_df['Batch ID'] = ambr_df['Batch ID'].replace('Bioreactor '+str(i),'R'+str(i))

# adding a column with the Reactor Number
online_data['Reactor/Plate/Flask Number'] = ambr_df['Batch ID'] # adding a column with the reactor ID
    
# dropping some unnecessary rows from the online data DataFrame:
online_data.dropna(axis=0, subset=['Inlet_air_O2'],inplace=True)
    
# updating index
online_data.index = range(0,len(online_data.index)) # updating the index of the dataframe
    
# Merging online data with cultures metadata
online_data = pd.merge(left=online_data,right=meta_data)
    
# phase annotation
feed_vol_list = online_data['Feed_volume'].tolist()
phase_list = ['feed' if i > 0.0 else 'batch' for i in feed_vol_list]
online_data['Phase'] = phase_list
online_data.head()
# Out:
#        Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0  0.000000  95.262961  6.512001     997.001937    29.910008  2.098002
# 1  0.033333  92.340531  6.515613    1001.231134    29.932312  2.199797
# 2  0.066667  90.291536  6.514060    1000.940172    29.980000  2.142014
# 3  0.100000  89.247083  6.513062     999.969053    30.000309  2.413068
# 4  0.133333  88.592080  6.513661    1000.000000    30.010000  2.152962
#
#      Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 0   99.965032          0.0         20.95  20.695004  ...
# 1  100.040850          0.0         20.95  20.685924  ...
# 2   99.945173          0.0         20.95  20.680353  ...
# 3  100.068347          0.0         20.95  20.693722  ...
# 4   99.984476          0.0         20.95  20.760625  ...
#
#    pH Control Base Solution  DO Control Setpoint (%)  \
# 0    Ammonium hydroxide 15%                       40
# 1    Ammonium hydroxide 15%                       40
# 2    Ammonium hydroxide 15%                       40
# 3    Ammonium hydroxide 15%                       40
# 4    Ammonium hydroxide 15%                       40
#
#    DO Control Cascade Level 1  DO Control Cascade Level 2  \
# 0                    Stirring                    Aeration
# 1                    Stirring                    Aeration
# 2                    Stirring                    Aeration
# 3                    Stirring                    Aeration
# 4                    Stirring                    Aeration
#
#    Minimum Aeration (slpm)  Maximum Aeration (slpm)  \
# 0                      0.1                     0.23
# 1                      0.1                     0.23
# 2                      0.1                     0.23
# 3                      0.1                     0.23
# 4                      0.1                     0.23
#
#    Minimum Stirring or Shaking Speed (rpm)  \
# 0                                     1000
# 1                                     1000
# 2                                     1000
# 3                                     1000
# 4                                     1000
#
#    Maximum Stirring or Shaking Speed (rpm)  Aeration Gas Type  Phase
# 0                                     4000                Air  batch
# 1                                     4000                Air  batch
# 2                                     4000                Air  batch
# 3                                     4000                Air  batch
# 4                                     4000                Air  batch
#
# [5 rows x 55 columns]

# %% [markdown]
# ### 3.2 Offline data

# %% [markdown]
# #### 3.2.1 Timepoint data

# %%
timepoint_cols = ['Entity','Experiment','Parent Culture','Reactor/Plate Number','Timepoint (#)','Timepoint (h)','Volume','OD']
file = data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx' # get the path to experimentin the LIMS file folder

timepoint_data = pd.read_excel(file, sheet_name='timepoint samples')[timepoint_cols] # importing timepoint data from one experiment into a temporary DFF

# renaming some of the columns in the dataframe and reindexing
timepoint_data.rename(columns={"Entity": "Timepoint Sample", "Reactor/Plate Number": "Reactor/Plate/Flask Number", "Volume": "Sample volume (mL)"},inplace=True)
timepoint_data = timepoint_data.reset_index().drop('index',axis=1)
timepoint_data.head()
# Out:
#           Timepoint Sample       Experiment  \
# 0  DDB_PD_045_AMBR_R01__S0  DDB_PD_045_AMBR
# 1  DDB_PD_045_AMBR_R01__S1  DDB_PD_045_AMBR
# 2  DDB_PD_045_AMBR_R01__S2  DDB_PD_045_AMBR
# 3  DDB_PD_045_AMBR_R01__S3  DDB_PD_045_AMBR
# 4  DDB_PD_045_AMBR_R01__S4  DDB_PD_045_AMBR
#
#                          Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 1  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 2  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 3  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 4  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD
# 0            S0       0.000000                   2   0.255
# 1            S1       9.019165                   4   5.840
# 2            S2      12.018681                   2  11.900
# 3            S3      16.611378                   2  22.700
# 4            S4      25.614764                   2  76.750

# %% [markdown]
# #### 3.2.2 Analytical data

# %%
analytical_cols = ['Name', 'Analysis Type', 'Cellular Compartment', 'Dilution Factor','Experiment', 'Parent Culture', 'Sample Prep Date', 'Timepoint (h)', 'Timepoint Sample', 'compound_name', 'concentration','concentration_unit']
    
analytical_data = pd.DataFrame(columns=analytical_cols) # initializing an empty DF for timepoint_data
file = data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx' # get the path to experiment in the LIMS file folder

analytical_data = pd.read_excel(file, sheet_name='analytical samples')[analytical_cols] # importing timepoint data from one experiment into a temporary DF

# renaming one of the columns in the dataframe and reindexing
analytical_data.rename(columns={"Name": "Analytical Sample"},inplace=True)
analytical_data = analytical_data.reset_index().drop('index',axis=1)

# correcting for the dilution factor, then dropping the dilution factor
analytical_data['concentration'] = analytical_data['concentration'] * analytical_data['Dilution Factor']
analytical_data.drop(['Dilution Factor'], axis=1, inplace=True)
# removing any analytical data not obtained from a main culture sample
analytical_data = analytical_data[analytical_data['Parent Culture'].notnull()]
analytical_data.head()
# Out:
#                 Analytical Sample Analysis Type  Cellular Compartment  \
# 0  DDB_PD_045_AMBR_R02__S7_SOA_#1           SOA  Extracellular Region
# 1  DDB_PD_045_AMBR_R02__S7_SOA_#1           SOA  Extracellular Region
# 2  DDB_PD_045_AMBR_R02__S7_SOA_#1           SOA  Extracellular Region
# 3  DDB_PD_045_AMBR_R02__S7_SOA_#1           SOA  Extracellular Region
# 4  DDB_PD_045_AMBR_R02__S7_SOA_#1           SOA  Extracellular Region
#
#         Experiment                        Parent Culture Sample Prep Date  \
# 0  DDB_PD_045_AMBR  DDB_PD_045_AMBR_SDT169-001_R02_Main_       2021-06-13
# 1  DDB_PD_045_AMBR  DDB_PD_045_AMBR_SDT169-001_R02_Main_       2021-06-13
# 2  DDB_PD_045_AMBR  DDB_PD_045_AMBR_SDT169-001_R02_Main_       2021-06-13
# 3  DDB_PD_045_AMBR  DDB_PD_045_AMBR_SDT169-001_R02_Main_       2021-06-13
# 4  DDB_PD_045_AMBR  DDB_PD_045_AMBR_SDT169-001_R02_Main_       2021-06-13
#
#    Timepoint (h)         Timepoint Sample  compound_name  concentration  \
# 0      36.482767  DDB_PD_045_AMBR_R02__S7  succinic acid            0.0
# 1      36.482767  DDB_PD_045_AMBR_R02__S7        ethanol            0.0
# 2      36.482767  DDB_PD_045_AMBR_R02__S7    citric acid            0.0
# 3      36.482767  DDB_PD_045_AMBR_R02__S7      D-glucose            0.0
# 4      36.482767  DDB_PD_045_AMBR_R02__S7    formic acid            0.0
#
#   concentration_unit
# 0                g/L
# 1                g/L
# 2                g/L
# 3                g/L
# 4                g/L

# %% [markdown]
# ##### 3.2.2.1 Pivot analytical data

# %%
analytical_data['compound_name_and_unit'] = analytical_data['compound_name'] + ' [' + analytical_data['concentration_unit'] + ']'

analytical_data_pivot = analytical_data.pivot(index='Timepoint Sample', columns=['compound_name_and_unit'], values='concentration')
analytical_data_pivot['Timepoint Sample'] = analytical_data_pivot.index

analytical_data_pivot.index.name = None
analytical_data_pivot.columns.name = None
analytical_data_pivot = analytical_data_pivot.reset_index().drop('index',axis=1)

analytical_data_pivot.head()
# Out:
#    D-glucose [g/L]  acetic acid [g/L]  citric acid [g/L]  ethanol [g/L]  \
# 0        24.411470           0.000000                0.0            0.0
# 1        18.222372           1.090570                0.0            0.0
# 2         9.945749           1.981059                0.0            0.0
# 3         0.000000           2.931551                0.0            0.0
# 4         0.000000           0.000000                0.0            0.0
#
#    formic acid [g/L]  lactate [g/L]  pyruvic acid [g/L]  succinic acid [g/L]  \
# 0                0.0       0.000000            0.000000             0.000000
# 1                0.0       0.557417            0.138991             0.000000
# 2                0.0       0.830801            0.229417             0.000000
# 3                0.0       0.000000            0.000000             0.000000
# 4                0.0       0.000000            0.000000             0.285568
#
#           Timepoint Sample
# 0  DDB_PD_045_AMBR_R01__S0
# 1  DDB_PD_045_AMBR_R01__S1
# 2  DDB_PD_045_AMBR_R01__S2
# 3  DDB_PD_045_AMBR_R01__S3
# 4  DDB_PD_045_AMBR_R01__S4

# %% [markdown]
# #### 3.2.3 Trace_metal_data

# %%
trace_metal_data = pd.read_excel(data_folder+'/LIMS_data/'+experiment+'_LIMS.xlsx', sheet_name='trace metal export')
trace_metal_data.rename(columns={'Name': 'Analytical Sample'}, inplace=True)

# timepoint_samples_temp = []
# for i in df_tm['Analytical Sample'].to_list():
#     timepoint_samples_temp.append(i.split('_TM')[0])

# df_tm['Timepoint Sample'] = timepoint_samples_temp
trace_metal_data['Timepoint Sample'] = trace_metal_data['Analytical Sample'].apply(lambda x: pd.Series(str(x).split("_TM")[0]))
trace_metal_data.head()
# Out:
# Empty DataFrame
# Columns: [Analytical Sample, compound_name, concentration, concentration_unit, Timepoint Sample]
# Index: []

# %% [markdown]
# ##### 3.2.2.1 Pivot trace metal data

# %%
trace_metal_data['compound_name_and_unit'] = trace_metal_data['compound_name'] + ' [' + trace_metal_data['concentration_unit'] + ']'

trace_metal_data_pivot = trace_metal_data.pivot(index='Timepoint Sample', columns=['compound_name_and_unit'], values='concentration')
trace_metal_data_pivot['Timepoint Sample'] = trace_metal_data_pivot.index

trace_metal_data_pivot.index.name = None
trace_metal_data_pivot.columns.name = None
trace_metal_data_pivot = trace_metal_data_pivot.reset_index().drop('index',axis=1)

trace_metal_data_pivot.head()
# Out:
# Empty DataFrame
# Columns: [Timepoint Sample]
# Index: []

# %% [markdown]
# #### 3.2.4 Custom data

# %%
try:
    custom_data = pd.read_excel(data_folder+'/custom_data_import_files/'+experiment+'_custom.xlsx')
    custom_data.head()
except:
    custom_data = pd.DataFrame(columns=['Timepoint Sample'])
    
custom_data
# Out:
# Empty DataFrame
# Columns: [Timepoint Sample]
# Index: []

# %% [markdown]
# #### 3.2.5 Merging all offline data

# %%
ac_merge = pd.merge(left=analytical_data_pivot, right=trace_metal_data_pivot, how='left')
custom_merge = pd.merge(left=ac_merge, right=custom_data, how='left')
offline_data = pd.merge(left=timepoint_data, right=custom_merge, how='left')
offline_data.head()
# Out:
#           Timepoint Sample       Experiment  \
# 0  DDB_PD_045_AMBR_R01__S0  DDB_PD_045_AMBR
# 1  DDB_PD_045_AMBR_R01__S1  DDB_PD_045_AMBR
# 2  DDB_PD_045_AMBR_R01__S2  DDB_PD_045_AMBR
# 3  DDB_PD_045_AMBR_R01__S3  DDB_PD_045_AMBR
# 4  DDB_PD_045_AMBR_R01__S4  DDB_PD_045_AMBR
#
#                          Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 1  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 2  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 3  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
# 4  DDB_PD_045_AMBR_SDT169-001_R01_Main_                        R01
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD  D-glucose [g/L]  \
# 0            S0       0.000000                   2   0.255        24.411470
# 1            S1       9.019165                   4   5.840        18.222372
# 2            S2      12.018681                   2  11.900         9.945749
# 3            S3      16.611378                   2  22.700         0.000000
# 4            S4      25.614764                   2  76.750         0.000000
#
#    acetic acid [g/L]  citric acid [g/L]  ethanol [g/L]  formic acid [g/L]  \
# 0           0.000000                0.0            0.0                0.0
# 1           1.090570                0.0            0.0                0.0
# 2           1.981059                0.0            0.0                0.0
# 3           2.931551                0.0            0.0                0.0
# 4           0.000000                0.0            0.0                0.0
#
#    lactate [g/L]  pyruvic acid [g/L]  succinic acid [g/L]
# 0       0.000000            0.000000             0.000000
# 1       0.557417            0.138991             0.000000
# 2       0.830801            0.229417             0.000000
# 3       0.000000            0.000000             0.000000
# 4       0.000000            0.000000             0.285568

# %% [markdown]
# ## 4. Export data

# %% [markdown]
# ### 4.2 Separate csv files

# %%
meta_data.to_csv('../../../data/fermentation_data_exports/' + experiment + '_meta_data_export.csv',index=False)
offline_data.to_csv('../../../data/fermentation_data_exports/' + experiment + '_offline_data_export.csv',index=False)
online_data.to_csv('../../../data/fermentation_data_exports/' + experiment + '_online_data_export.csv',index=False)
