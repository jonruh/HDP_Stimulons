# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
from scipy import stats
import math

# %%
# DDB_PD_123_AMBR_SDT202-002_R15_Main_ failed

# %% [markdown]
# ## Load and edit data

# %% [markdown]
# ### Load and edit meta data

# %%
meta_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_005_AMBR_meta_data_export.csv')
meta_df_2 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_006_AMBR_meta_data_export.csv')
meta_df_3 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_009_AMBR_meta_data_export.csv')
meta_df_4 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_036_AMBR_meta_data_export.csv')
meta_df_5 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_045_AMBR_meta_data_export.csv')
meta_df_6 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_060_AMBR_meta_data_export.csv')
meta_df_7 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_065_AMBR_meta_data_export.csv')
meta_df_8 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_066_AMBR_meta_data_export.csv')
meta_df_9 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_067_AMBR_meta_data_export.csv')
meta_df_10 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_073_AMBR_meta_data_export.csv')
# meta_df_11 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_111_AMBR_meta_data_export.csv')
meta_df_12 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_116_AMBR_meta_data_export.csv')
meta_df_13 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_117_AMBR_meta_data_export.csv')
meta_df_14 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_121_AMBR_meta_data_export.csv')
meta_df_15 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_122_AMBR_meta_data_export.csv')
meta_df_16 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_123_AMBR_meta_data_export.csv')
meta_df_16 = meta_df_16[~(meta_df_16['Parent Culture'] == 'DDB_PD_123_AMBR_SDT202-002_R15_Main_')].reset_index().drop('index',axis=1)
# meta_df_17 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_138_AMBR_meta_data_export.csv')
# meta_df_18 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_139_AMBR_meta_data_export.csv')

meta_df =pd.concat([meta_df_1,meta_df_2,meta_df_3,meta_df_4,meta_df_5,meta_df_6,meta_df_7,meta_df_8,meta_df_9,meta_df_10,meta_df_12,meta_df_13,meta_df_14,meta_df_15,meta_df_16]).reset_index().drop('index',axis=1)
meta_df.head()
# Out:
#                         Parent Culture Base Medium Container ID (calculated)  \
# 0   DDB_PD_005_AMBR_DDB7-002_R01_Main_  DDB_BM_002                       R01
# 1   DDB_PD_005_AMBR_DDB7-002_R02_Main_  DDB_BM_002                       R02
# 2  DDB_PD_005_AMBR_DDB12-001_R03_Main_  DDB_BM_002                       R03
# 3  DDB_PD_005_AMBR_DDB12-001_R04_Main_  DDB_BM_002                       R04
# 4  DDB_PD_005_AMBR_DDB15-001_R05_Main_  DDB_BM_002                       R05
#
#   Container Type Control? Culture Type       Experiment Experiment Annotation  \
# 0       AMBR 250       No         Main  DDB_PD_005_AMBR    DDB Quorum Sensing
# 1       AMBR 250       No         Main  DDB_PD_005_AMBR    DDB Quorum Sensing
# 2       AMBR 250       No         Main  DDB_PD_005_AMBR    DDB Quorum Sensing
# 3       AMBR 250       No         Main  DDB_PD_005_AMBR    DDB Quorum Sensing
# 4       AMBR 250       No         Main  DDB_PD_005_AMBR    DDB Quorum Sensing
#
#    growth_rate Feed Medium #1  ... Aeration Gas Type  Final Seed OD  \
# 0         0.11     DDB_FM_002  ...               Air         5.6425
# 1         0.11     DDB_FM_002  ...               Air         5.6425
# 2         0.11     DDB_FM_002  ...               Air         5.5675
# 3         0.11     DDB_FM_002  ...               Air         5.5675
# 4         0.11     DDB_FM_002  ...               Air         5.8925
#
#   Volume to AddNone Volume AddedNone Volume UnitNone  Inoculate Date/Time  \
# 0          3.544528             3.67              mL  2020-08-18 10:00:00
# 1          3.544528             3.67              mL  2020-08-18 10:00:00
# 2          3.592277             3.73              mL  2020-08-18 10:00:00
# 3          3.592277             3.73              mL  2020-08-18 10:00:00
# 4          3.394145             3.51              mL  2020-08-18 11:00:00
#
#   Comments  DO Control Cascade Level 3  Feed #1 Profile  Condition
# 0      NaN                         NaN              NaN        NaN
# 1      NaN                         NaN              NaN        NaN
# 2      NaN                         NaN              NaN        NaN
# 3      NaN                         NaN              NaN        NaN
# 4      NaN                         NaN              NaN        NaN
#
# [5 rows x 38 columns]

# %% [markdown]
# ### Load online data

# %%
online_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_005_AMBR_online_data_export.csv')
online_df_2 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_006_AMBR_online_data_export.csv')
online_df_3 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_009_AMBR_online_data_export.csv')
online_df_4 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_036_AMBR_online_data_export.csv')
online_df_5 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_045_AMBR_online_data_export.csv')
online_df_6 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_060_AMBR_online_data_export.csv')
online_df_7 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_065_AMBR_online_data_export.csv')
online_df_8 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_066_AMBR_online_data_export.csv')
online_df_9 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_067_AMBR_online_data_export.csv')
online_df_10 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_073_AMBR_online_data_export.csv')
# online_df_11 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_111_AMBR_online_data_export.csv')
online_df_12 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_116_AMBR_online_data_export.csv')
online_df_13 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_117_AMBR_online_data_export.csv')
online_df_14 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_121_AMBR_online_data_export.csv')
online_df_15 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_122_AMBR_online_data_export.csv')
online_df_16 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_123_AMBR_online_data_export.csv')
online_df_16 = online_df_16[~(online_df_16['Reactor/Plate/Flask Number'] == 'R15')].reset_index().drop('index',axis=1)
# online_df_17 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_138_AMBR_online_data_export.csv')
# online_df_18 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_139_AMBR_online_data_export.csv')

online_df =pd.concat([online_df_1,online_df_2,online_df_3,online_df_4,online_df_5,online_df_6,online_df_7,online_df_8,online_df_9,online_df_10,online_df_12,online_df_13,online_df_14,online_df_15,online_df_16]).reset_index().drop('index',axis=1)
online_df.head()
# Out:
#        Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0  0.000000  93.420257  6.588931    1000.863155    29.969999  2.625100
# 1  0.033333  92.407015  6.588931     999.000000    30.000000  0.124776
# 2  0.066667  91.897315  6.589056    1000.117931    30.011180  2.507053
# 3  0.100000  91.624246  6.588078    1004.455012    30.030001  2.344355
# 4  0.133333  91.619059  6.589123    1001.030660    30.030001  2.554748
#
#      Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  Final Seed OD  \
# 0   99.969935          0.0         20.95  20.665001  ...         5.6425
# 1   99.999790          0.0         20.95  20.662535  ...         5.6425
# 2   99.987134          0.0         20.95  20.645826  ...         5.6425
# 3  100.037407          0.0         20.95  20.652922  ...         5.6425
# 4   99.945202          0.0         20.95  20.670846  ...         5.6425
#
#    Volume to AddNone  Volume AddedNone  Volume UnitNone  Inoculate Date/Time  \
# 0           3.544528              3.67               mL  2020-08-18 10:00:00
# 1           3.544528              3.67               mL  2020-08-18 10:00:00
# 2           3.544528              3.67               mL  2020-08-18 10:00:00
# 3           3.544528              3.67               mL  2020-08-18 10:00:00
# 4           3.544528              3.67               mL  2020-08-18 10:00:00
#
#    Phase  Comments  DO Control Cascade Level 3  Feed #1 Profile  Condition
# 0  batch       NaN                         NaN              NaN        NaN
# 1  batch       NaN                         NaN              NaN        NaN
# 2  batch       NaN                         NaN              NaN        NaN
# 3  batch       NaN                         NaN              NaN        NaN
# 4  batch       NaN                         NaN              NaN        NaN
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Load and edit offline data

# %%
offline_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_005_AMBR_offline_data_export.csv')
offline_df_2 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_006_AMBR_offline_data_export.csv')
offline_df_3 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_009_AMBR_offline_data_export.csv')
offline_df_4 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_036_AMBR_offline_data_export.csv')
offline_df_5 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_045_AMBR_offline_data_export.csv')
offline_df_6 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_060_AMBR_offline_data_export.csv')
offline_df_7 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_065_AMBR_offline_data_export.csv')
offline_df_8 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_066_AMBR_offline_data_export.csv')
offline_df_9 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_067_AMBR_offline_data_export.csv')
offline_df_10 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_073_AMBR_offline_data_export.csv')
# offline_df_11 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_111_AMBR_offline_data_export.csv')
offline_df_12 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_116_AMBR_offline_data_export.csv')
offline_df_13 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_117_AMBR_offline_data_export.csv')
offline_df_14 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_121_AMBR_offline_data_export.csv')
offline_df_15 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_122_AMBR_offline_data_export.csv')
offline_df_16 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_123_AMBR_offline_data_export.csv')
offline_df_16 = offline_df_16[~(offline_df_16['Parent Culture'] == 'DDB_PD_123_AMBR_SDT202-002_R15_Main_')].reset_index().drop('index',axis=1)
# offline_df_17 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_138_AMBR_offline_data_export.csv')
# offline_df_18 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_139_AMBR_offline_data_export.csv')

offline_df =pd.concat([offline_df_1,offline_df_2,offline_df_3,offline_df_4,offline_df_5,offline_df_6,offline_df_7,offline_df_8,offline_df_9,offline_df_10,offline_df_12,offline_df_13,offline_df_14,offline_df_15,offline_df_16]).reset_index().drop('index',axis=1)
# merge with metadata to filter by when plotting
offline_df = pd.merge(left=offline_df,right=meta_df[['Parent Culture','Strain Batch','Base Medium','growth_rate']],how='left')
offline_df.head()
# Out:
#            Timepoint Sample       Experiment  \
# 0  DDB_PD_005_AMBR_R01__S00  DDB_PD_005_AMBR
# 1  DDB_PD_005_AMBR_R01__S01  DDB_PD_005_AMBR
# 2  DDB_PD_005_AMBR_R01__S02  DDB_PD_005_AMBR
# 3  DDB_PD_005_AMBR_R01__S03  DDB_PD_005_AMBR
# 4  DDB_PD_005_AMBR_R01__S04  DDB_PD_005_AMBR
#
#                        Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 1  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 2  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 3  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 4  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD  D-glucose [g/L]  \
# 0           S00       0.036495                 1.0   0.256        21.867193
# 1           S01       3.047016                 1.0   0.628        21.757897
# 2           S02       6.018670                 2.5   1.800        20.801498
# 3           S03       9.016564                 1.0   5.365        16.772116
# 4           S04      12.019295                 1.0  14.650         9.421337
#
#    acetic acid [g/L]  ...  na [mg/L]  s [mg/L]  tryptophan [g/L]  CDW_1 [g/L]  \
# 0           0.000000  ...        NaN       NaN               NaN          NaN
# 1           0.000000  ...        NaN       NaN               NaN          NaN
# 2           0.129068  ...        NaN       NaN               NaN          NaN
# 3           0.362876  ...        NaN       NaN               NaN          NaN
# 4           0.568955  ...        NaN       NaN               NaN          NaN
#
#    CDW_2 [g/L]  CDW_3 [g/L]  lactose [g/L]  Strain Batch  Base Medium  \
# 0          NaN          NaN            NaN      DDB7-002   DDB_BM_002
# 1          NaN          NaN            NaN      DDB7-002   DDB_BM_002
# 2          NaN          NaN            NaN      DDB7-002   DDB_BM_002
# 3          NaN          NaN            NaN      DDB7-002   DDB_BM_002
# 4          NaN          NaN            NaN      DDB7-002   DDB_BM_002
#
#    growth_rate
# 0         0.11
# 1         0.11
# 2         0.11
# 3         0.11
# 4         0.11
#
# [5 rows x 41 columns]

# %%
meta_df["Base Medium"].unique()
# Out:
# array(['DDB_BM_002', 'DDB_BM_PD60_R06', 'DDB_BM_PD60_R07',
#        'DDB_BM_PD60_R08', 'DDB_BM_PD60_R09', 'DDB_BM_PD60_R10',
#        'DDB_BM_PD60_R11', 'DDB_BM_005', 'DDB_BM_003', 'DDB_BM_006',
#        'DDB_BM_016', 'DDB_BM_015'], dtype=object)

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df.head()
# Out:
#                         Parent Culture  batch_end
# 0  DDB_PD_005_AMBR_DDB12-001_R03_Main_  17.500000
# 1  DDB_PD_005_AMBR_DDB12-001_R04_Main_  14.766667
# 2  DDB_PD_005_AMBR_DDB15-001_R05_Main_  13.533333
# 3  DDB_PD_005_AMBR_DDB15-001_R06_Main_  13.633333
# 4  DDB_PD_005_AMBR_DDB16-001_R07_Main_  15.333333

# %%
# merge batch end times into offlien data
offline_df = pd.merge(left=offline_df,right=batch_end_df,how='left')
offline_df['feed_time'] = offline_df['Timepoint (h)'] - offline_df['batch_end']

# %%
# average technical replicates of cell dry weight
offline_df['CDW_avg [g/L]'] = offline_df[['CDW_1 [g/L]','CDW_2 [g/L]','CDW_3 [g/L]']].mean(axis=1)

# %% [markdown]
# #### Derive CDW from OD, where missing

# %%
sns.scatterplot(
    data=offline_df,
    y="CDW_avg [g/L]",
    x="OD"
)

xy_data = offline_df[["CDW_avg [g/L]", "OD"]]
xy_data.dropna(inplace=True)

x = xy_data["OD"]
y = xy_data["CDW_avg [g/L]"]

#regression part
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

line = slope*x+intercept
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.legend(fontsize=9)
# Out:
# C:\Users\jonas\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %%
CDW_list = []
correlated_CDW_list = []

for i in range(0, len(offline_df)):
    if (math.isnan(offline_df.iloc[i]["CDW_avg [g/L]"])) & (not math.isnan(offline_df.iloc[i]["OD"])):
        CDW_list.append(0.29*offline_df.iloc[i]["OD"])
        correlated_CDW_list.append("yes")
        
    elif (math.isnan(offline_df.iloc[i]["CDW_avg [g/L]"])) & (math.isnan(offline_df.iloc[i]["OD"])):
        CDW_list.append(0.29*offline_df.iloc[i]["OD"])
        correlated_CDW_list.append("no_biomass_data")
        
    else:
        CDW_list.append(offline_df.iloc[i]["CDW_avg [g/L]"])
        correlated_CDW_list.append("no")
        
offline_df["correlated_CDW"] = correlated_CDW_list
offline_df["CDW_avg [g/L]"] = CDW_list

# %%
sns.scatterplot(
    data=offline_df,
    y="CDW_avg [g/L]",
    x="OD",
    hue="correlated_CDW"
)

xy_data = offline_df[["CDW_avg [g/L]", "OD"]]
xy_data.dropna(inplace=True)

x = xy_data["OD"]
y = xy_data["CDW_avg [g/L]"]

#regression part
slope, intercept, r_value, p_value, std_err = stats.linregress(x,y)

line = slope*x+intercept
plt.plot(x, line, 'r', label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.legend(fontsize=9)
# Out:
# C:\Users\jonas\anaconda3\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)

# %% [markdown]
# ### Edit online data

# %% [markdown]
# #### Subtracting batch end time

# %%
# merge with metadata to filter by when plotting
online_df = pd.merge(left=online_df,right=meta_df[['Parent Culture','Strain Batch']],how='left')
# need to fill nan feed volumes with 0 in online data
online_df['Feed_volume'] = online_df['Feed_volume'].fillna(0)

# %%
online_df['Condition'].unique()
# Out:
# array([nan, 'mu = 0.05 exponential feed', 'mu = 0.1 exponential feed'],
#       dtype=object)

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df
# Out:
#                            Parent Culture  batch_end
# 0     DDB_PD_005_AMBR_DDB12-001_R03_Main_  17.500000
# 1     DDB_PD_005_AMBR_DDB12-001_R04_Main_  14.766667
# 2     DDB_PD_005_AMBR_DDB15-001_R05_Main_  13.533333
# 3     DDB_PD_005_AMBR_DDB15-001_R06_Main_  13.633333
# 4     DDB_PD_005_AMBR_DDB16-001_R07_Main_  15.333333
# ..                                    ...        ...
# 128   DDB_PD_123_AMBR_DDB35-006_R05_Main_  14.833333
# 129  DDB_PD_123_AMBR_SDT173-002_R07_Main_  15.366667
# 130  DDB_PD_123_AMBR_SDT178-002_R09_Main_  22.100000
# 131  DDB_PD_123_AMBR_SDT180-003_R11_Main_  20.933333
# 132  DDB_PD_123_AMBR_SDT201-002_R13_Main_  16.200000
#
# [133 rows x 2 columns]

# %%
# merge batch end times into online data
online_df = pd.merge(left=online_df,right=batch_end_df,how='left')
online_df['feed_time'] = online_df['Time'] - online_df['batch_end']

# %%
# round values
online_df['feed_time'] = np.round(online_df['feed_time'].values,4)

# %% [markdown]
# ### Mol and Cmol conversions

# %% [markdown]
# #### Functions

# %%
def mass_to_mol(new_mol_col,mass_col,compound_mol_mass):
    offline_df[new_mol_col] = offline_df[mass_col]/compound_mol_mass

def mol_to_cmol(new_cmol_col,mol_col,n_c):
    offline_df[new_cmol_col] = offline_df[mol_col]*n_c

# %% [markdown]
# #### Biomass

# %%
new_mol_col = 'CDW_avg_molar'
mass_col = 'CDW_avg [g/L]'
compound_mol_mass = 24.6
new_cmol_col = 'CDW_avg_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Glucose

# %%
new_mol_col = 'glucose_molar'
mass_col = 'D-glucose [g/L]'
compound_mol_mass = 180.156
new_cmol_col = 'glucose_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Tryptophan

# %%
new_mol_col = 'tryptophan_molar'
mass_col = 'tryptophan [g/L]'
compound_mol_mass = 204.23
new_cmol_col = 'tryptophan_cmolar'
mol_col = new_mol_col
n_c = 11

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Acetate

# %%
new_mol_col = 'acetic_acid_molar'
mass_col = 'acetic acid [g/L]'
compound_mol_mass = 60.052 
new_cmol_col = 'acetic_acid_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Citrate

# %%
new_mol_col = 'citric_acid_molar'
mass_col = 'citric acid [g/L]'
compound_mol_mass = 192.124
new_cmol_col = 'citric_acid_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Ethanol

# %%
new_mol_col = 'ethanol_molar'
mass_col = 'ethanol [g/L]'
compound_mol_mass = 46.07
new_cmol_col = 'ethanol_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Formate

# %%
new_mol_col = 'formic_acid_molar'
mass_col = 'formic acid [g/L]'
compound_mol_mass = 46.03
new_cmol_col = 'formic_acid_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Lactate

# %%
new_mol_col = 'lactate_molar'
mass_col = 'lactate [g/L]'
compound_mol_mass = 90.08
new_cmol_col = 'lactate_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Pyruvate

# %%
new_mol_col = 'pyruvic_acid_molar'
mass_col = 'pyruvic acid [g/L]'
compound_mol_mass = 88.06
new_cmol_col = 'pyruvic_acid_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Succinate

# %%
new_mol_col = 'succinic_acid_molar'
mass_col = 'succinic acid [g/L]'
compound_mol_mass = 118.09
new_cmol_col = 'succinic_acid_cmolar'
mol_col = new_mol_col
n_c = 4

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# ### Advanced calculations

# %% [markdown]
# #### Functions

# %%
def lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col):
    offline_df[new_lost_col] = offline_df[measurement_col] * offline_df['Sample volume (mL)']/1000
    offline_df[new_lost_cumsum_col] = offline_df.groupby(['Parent Culture']).cumsum()[new_lost_col]
    offline_df[new_lost_cumsum_col] = offline_df.groupby('Parent Culture').shift()[new_lost_cumsum_col].fillna(0)
    
def net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = offline_df[residual_col]*offline_df['Liquid_volume']/1000 + offline_df[lost_cumsum_col] - init_amount - feed_conc*offline_df['Feed_volume']/1000
    
def net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = -offline_df[residual_col]*offline_df['Liquid_volume']/1000 - offline_df[lost_cumsum_col] + init_amount + feed_conc*offline_df['Feed_volume']/1000

# %% [markdown]
# #### Lost masses (due to sampling) calculations

# %% [markdown]
# ##### Lost biomass (cmol)

# %%
new_lost_col = 'lost_biomass_cmol'
new_lost_cumsum_col = 'lost_biomass_cumsum_cmol'
measurement_col = 'CDW_avg_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost biomass (g)

# %%
new_lost_col = 'lost_biomass_g'
new_lost_cumsum_col = 'lost_biomass_cumsum_g'
measurement_col = 'CDW_avg [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (cmol)

# %%
new_lost_col = 'lost_glucose_cmol'
new_lost_cumsum_col = 'lost_glucose_cumsum_cmol'
measurement_col = 'glucose_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (g)

# %%
new_lost_col = 'lost_glucose_g'
new_lost_cumsum_col = 'lost_glucose_cumsum_g'
measurement_col = 'D-glucose [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost tryptophan (cmol)

# %%
new_lost_col = 'lost_tryptophan_cmol'
new_lost_cumsum_col = 'lost_tryptophan_cumsum_cmol'
measurement_col = 'tryptophan_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost acetate (cmol)

# %%
new_lost_col = 'lost_acetic_acid_cmol'
new_lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
measurement_col = 'acetic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost citrate (cmol)

# %%
new_lost_col = 'lost_citric_acid_cmol'
new_lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
measurement_col = 'citric_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost ethanol (cmol)

# %%
new_lost_col = 'lost_ethanol_cmol'
new_lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
measurement_col = 'ethanol_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost formate (cmol)

# %%
new_lost_col = 'lost_formic_acid_cmol'
new_lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
measurement_col = 'formic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost lactate (cmol)

# %%
new_lost_col = 'lost_lactate_cmol'
new_lost_cumsum_col = 'lost_lactate_cumsum_cmol'
measurement_col = 'lactate_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost pyruvate (cmol)

# %%
new_lost_col = 'lost_pyruvic_acid_cmol'
new_lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
measurement_col = 'pyruvic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost succinate (cmol)

# %%
new_lost_col = 'lost_succinic_acid_cmol'
new_lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
measurement_col = 'succinic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost metals

# %%
new_lost_col = "lost_co_µg"
new_lost_cumsum_col = "lost_co_cumsum_µg"
measurement_col = "co [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_cu_µg"
new_lost_cumsum_col = "lost_cu_cumsum_µg"
measurement_col = "cu [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_fe_µg"
new_lost_cumsum_col = "lost_fe_cumsum_µg"
measurement_col = "fe [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_mg_mg"
new_lost_cumsum_col = "lost_mg_cumsum_mg"
measurement_col = "mg [mg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_mn_µg"
new_lost_cumsum_col = "lost_mn_cumsum_µg"
measurement_col = "mn [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_mo_µg"
new_lost_cumsum_col = "lost_mo_cumsum_µg"
measurement_col = "mo [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

new_lost_col = "lost_zn_µg"
new_lost_cumsum_col = "lost_zn_cumsum_µg"
measurement_col = "zn [µg/L]"
lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# #### Liquid and feeding volume from online data into offline data

# %%
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
slice_offline_df
# Out:
#                             Parent Culture       Time Timepoint (#)
# 0       DDB_PD_005_AMBR_DDB7-002_R01_Main_   0.036495           S00
# 1       DDB_PD_005_AMBR_DDB7-002_R01_Main_   3.047016           S01
# 2       DDB_PD_005_AMBR_DDB7-002_R01_Main_   6.018670           S02
# 3       DDB_PD_005_AMBR_DDB7-002_R01_Main_   9.016564           S03
# 4       DDB_PD_005_AMBR_DDB7-002_R01_Main_  12.019295           S04
# ...                                    ...        ...           ...
# 1240  DDB_PD_123_AMBR_SDT201-002_R13_Main_  12.035416           S01
# 1241  DDB_PD_123_AMBR_SDT201-002_R13_Main_  16.157046           S02
# 1242  DDB_PD_123_AMBR_SDT201-002_R13_Main_  36.227630           S03
# 1243  DDB_PD_123_AMBR_SDT201-002_R13_Main_  56.433416           S04
# 1244  DDB_PD_123_AMBR_SDT201-002_R13_Main_  76.199868           S05
#
# [1245 rows x 3 columns]

# %%
df = pd.concat([online_df,slice_offline_df])
df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0      0.000000  93.420257  6.588931    1000.863155    29.969999  2.625100
# 1      0.033333  92.407015  6.588931     999.000000    30.000000  0.124776
# 2      0.066667  91.897315  6.589056    1000.117931    30.011180  2.507053
# 3      0.100000  91.624246  6.588078    1004.455012    30.030001  2.344355
# 4      0.133333  91.619059  6.589123    1001.030660    30.030001  2.554748
# ...         ...        ...       ...            ...          ...       ...
# 1240  12.035416        NaN       NaN            NaN          NaN       NaN
# 1241  16.157046        NaN       NaN            NaN          NaN       NaN
# 1242  36.227630        NaN       NaN            NaN          NaN       NaN
# 1243  56.433416        NaN       NaN            NaN          NaN       NaN
# 1244  76.199868        NaN       NaN            NaN          NaN       NaN
#
#         Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  Volume UnitNone  \
# 0      99.969935          0.0         20.95  20.665001  ...               mL
# 1      99.999790          0.0         20.95  20.662535  ...               mL
# 2      99.987134          0.0         20.95  20.645826  ...               mL
# 3     100.037407          0.0         20.95  20.652922  ...               mL
# 4      99.945202          0.0         20.95  20.670846  ...               mL
# ...          ...          ...           ...        ...  ...              ...
# 1240         NaN          NaN           NaN        NaN  ...              NaN
# 1241         NaN          NaN           NaN        NaN  ...              NaN
# 1242         NaN          NaN           NaN        NaN  ...              NaN
# 1243         NaN          NaN           NaN        NaN  ...              NaN
# 1244         NaN          NaN           NaN        NaN  ...              NaN
#
#       Inoculate Date/Time  Phase  Comments  DO Control Cascade Level 3  \
# 0     2020-08-18 10:00:00  batch       NaN                         NaN
# 1     2020-08-18 10:00:00  batch       NaN                         NaN
# 2     2020-08-18 10:00:00  batch       NaN                         NaN
# 3     2020-08-18 10:00:00  batch       NaN                         NaN
# 4     2020-08-18 10:00:00  batch       NaN                         NaN
# ...                   ...    ...       ...                         ...
# 1240                  NaN    NaN       NaN                         NaN
# 1241                  NaN    NaN       NaN                         NaN
# 1242                  NaN    NaN       NaN                         NaN
# 1243                  NaN    NaN       NaN                         NaN
# 1244                  NaN    NaN       NaN                         NaN
#
#       Feed #1 Profile  Condition  batch_end  feed_time  Timepoint (#)
# 0                 NaN        NaN  14.433333   -14.4333            NaN
# 1                 NaN        NaN  14.433333   -14.4000            NaN
# 2                 NaN        NaN  14.433333   -14.3667            NaN
# 3                 NaN        NaN  14.433333   -14.3333            NaN
# 4                 NaN        NaN  14.433333   -14.3000            NaN
# ...               ...        ...        ...        ...            ...
# 1240              NaN        NaN        NaN        NaN            S01
# 1241              NaN        NaN        NaN        NaN            S02
# 1242              NaN        NaN        NaN        NaN            S03
# 1243              NaN        NaN        NaN        NaN            S04
# 1244              NaN        NaN        NaN        NaN            S05
#
# [187940 rows x 66 columns]

# %%
df.sort_values(['Parent Culture','Time'],inplace=True)
df
# Out:
#              Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 1886     0.000000  92.737871  6.510984     999.007708    29.940001  3.034349
# 1887     0.033333  91.194826  6.515370    1003.210949    29.992630  2.918408
# 1888     0.066667  90.260326  6.508922    1001.078085    30.020000  2.381288
# 22       0.070744        NaN       NaN            NaN          NaN       NaN
# 1889     0.100000  89.937760  6.505657    1001.447505    30.030001  2.976313
# ...           ...        ...       ...            ...          ...       ...
# 186690  76.233333  47.045038  6.477099    4001.551797    29.980000  7.299418
# 186691  76.266667  46.417059  6.479275    3996.791024    29.990000  7.702876
# 186692  76.300000  47.110639  6.478715    4004.287796    29.980000  7.085293
# 186693  76.333333  48.153894  6.490699    4016.023436    29.960375  6.776949
# 186694  76.366667  48.437991  6.469002    3993.006664    29.959999  7.548963
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 1886    100.070768     0.000000     20.950000  20.656000  ...
# 1887    100.037415     0.000000     20.950000  20.654737  ...
# 1888     99.783165     0.000000     20.950000  20.650538  ...
# 22             NaN          NaN           NaN        NaN  ...
# 1889    100.177269     0.000000     20.950000  20.645104  ...
# ...            ...          ...           ...        ...  ...
# 186690  150.587838     5.023408     23.501915  17.175349  ...
# 186691  149.795862     4.987297     23.497090  17.110758  ...
# 186692  150.659769     5.016724     23.497410  17.743094  ...
# 186693  150.903896     4.973615     23.472286  17.341886  ...
# 186694  149.911826     4.995002     23.498983  17.337998  ...
#
#         Volume UnitNone  Inoculate Date/Time  Phase  Comments  \
# 1886                 mL  2020-08-18 10:00:00  batch       NaN
# 1887                 mL  2020-08-18 10:00:00  batch       NaN
# 1888                 mL  2020-08-18 10:00:00  batch       NaN
# 22                  NaN                  NaN    NaN       NaN
# 1889                 mL  2020-08-18 10:00:00  batch       NaN
# ...                 ...                  ...    ...       ...
# 186690              NaN                  NaN   feed       NaN
# 186691              NaN                  NaN   feed       NaN
# 186692              NaN                  NaN   feed       NaN
# 186693              NaN                  NaN   feed       NaN
# 186694              NaN                  NaN   feed       NaN
#
#         DO Control Cascade Level 3  Feed #1 Profile  Condition  batch_end  \
# 1886                           NaN              NaN        NaN       17.5
# 1887                           NaN              NaN        NaN       17.5
# 1888                           NaN              NaN        NaN       17.5
# 22                             NaN              NaN        NaN        NaN
# 1889                           NaN              NaN        NaN       17.5
# ...                            ...              ...        ...        ...
# 186690                      Oxygen              NaN        NaN       16.2
# 186691                      Oxygen              NaN        NaN       16.2
# 186692                      Oxygen              NaN        NaN       16.2
# 186693                      Oxygen              NaN        NaN       16.2
# 186694                      Oxygen              NaN        NaN       16.2
#
#         feed_time  Timepoint (#)
# 1886     -17.5000            NaN
# 1887     -17.4667            NaN
# 1888     -17.4333            NaN
# 22            NaN            S00
# 1889     -17.4000            NaN
# ...           ...            ...
# 186690    60.0333            NaN
# 186691    60.0667            NaN
# 186692    60.1000            NaN
# 186693    60.1333            NaN
# 186694    60.1667            NaN
#
# [187940 rows x 66 columns]

# %%
df['Liquid_volume'] = df['Liquid_volume'].fillna(method='bfill')
df['Feed_volume'] = df['Feed_volume'].fillna(method='bfill')
df
# Out:
#              Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 1886     0.000000  92.737871  6.510984     999.007708    29.940001  3.034349
# 1887     0.033333  91.194826  6.515370    1003.210949    29.992630  2.918408
# 1888     0.066667  90.260326  6.508922    1001.078085    30.020000  2.381288
# 22       0.070744        NaN       NaN            NaN          NaN       NaN
# 1889     0.100000  89.937760  6.505657    1001.447505    30.030001  2.976313
# ...           ...        ...       ...            ...          ...       ...
# 186690  76.233333  47.045038  6.477099    4001.551797    29.980000  7.299418
# 186691  76.266667  46.417059  6.479275    3996.791024    29.990000  7.702876
# 186692  76.300000  47.110639  6.478715    4004.287796    29.980000  7.085293
# 186693  76.333333  48.153894  6.490699    4016.023436    29.960375  6.776949
# 186694  76.366667  48.437991  6.469002    3993.006664    29.959999  7.548963
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  \
# 1886    100.070768     0.000000     20.950000  20.656000  ...
# 1887    100.037415     0.000000     20.950000  20.654737  ...
# 1888     99.783165     0.000000     20.950000  20.650538  ...
# 22             NaN          NaN           NaN        NaN  ...
# 1889    100.177269     0.000000     20.950000  20.645104  ...
# ...            ...          ...           ...        ...  ...
# 186690  150.587838     5.023408     23.501915  17.175349  ...
# 186691  149.795862     4.987297     23.497090  17.110758  ...
# 186692  150.659769     5.016724     23.497410  17.743094  ...
# 186693  150.903896     4.973615     23.472286  17.341886  ...
# 186694  149.911826     4.995002     23.498983  17.337998  ...
#
#         Volume UnitNone  Inoculate Date/Time  Phase  Comments  \
# 1886                 mL  2020-08-18 10:00:00  batch       NaN
# 1887                 mL  2020-08-18 10:00:00  batch       NaN
# 1888                 mL  2020-08-18 10:00:00  batch       NaN
# 22                  NaN                  NaN    NaN       NaN
# 1889                 mL  2020-08-18 10:00:00  batch       NaN
# ...                 ...                  ...    ...       ...
# 186690              NaN                  NaN   feed       NaN
# 186691              NaN                  NaN   feed       NaN
# 186692              NaN                  NaN   feed       NaN
# 186693              NaN                  NaN   feed       NaN
# 186694              NaN                  NaN   feed       NaN
#
#         DO Control Cascade Level 3  Feed #1 Profile  Condition  batch_end  \
# 1886                           NaN              NaN        NaN       17.5
# 1887                           NaN              NaN        NaN       17.5
# 1888                           NaN              NaN        NaN       17.5
# 22                             NaN              NaN        NaN        NaN
# 1889                           NaN              NaN        NaN       17.5
# ...                            ...              ...        ...        ...
# 186690                      Oxygen              NaN        NaN       16.2
# 186691                      Oxygen              NaN        NaN       16.2
# 186692                      Oxygen              NaN        NaN       16.2
# 186693                      Oxygen              NaN        NaN       16.2
# 186694                      Oxygen              NaN        NaN       16.2
#
#         feed_time  Timepoint (#)
# 1886     -17.5000            NaN
# 1887     -17.4667            NaN
# 1888     -17.4333            NaN
# 22            NaN            S00
# 1889     -17.4000            NaN
# ...           ...            ...
# 186690    60.0333            NaN
# 186691    60.0667            NaN
# 186692    60.1000            NaN
# 186693    60.1333            NaN
# 186694    60.1667            NaN
#
# [187940 rows x 66 columns]

# %%
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
df
# Out:
#            Time  DO  pH  Stirrer_speed  Temperature  Pressure  Air_flow  \
# 22     0.070744 NaN NaN            NaN          NaN       NaN       NaN
# 23     3.082238 NaN NaN            NaN          NaN       NaN       NaN
# 24     6.071009 NaN NaN            NaN          NaN       NaN       NaN
# 25     9.053241 NaN NaN            NaN          NaN       NaN       NaN
# 26    12.055890 NaN NaN            NaN          NaN       NaN       NaN
# ...         ...  ..  ..            ...          ...       ...       ...
# 1240  12.035416 NaN NaN            NaN          NaN       NaN       NaN
# 1241  16.157046 NaN NaN            NaN          NaN       NaN       NaN
# 1242  36.227630 NaN NaN            NaN          NaN       NaN       NaN
# 1243  56.433416 NaN NaN            NaN          NaN       NaN       NaN
# 1244  76.199868 NaN NaN            NaN          NaN       NaN       NaN
#
#       Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  Volume UnitNone  \
# 22            NaN           NaN        NaN  ...              NaN
# 23            NaN           NaN        NaN  ...              NaN
# 24            NaN           NaN        NaN  ...              NaN
# 25            NaN           NaN        NaN  ...              NaN
# 26            NaN           NaN        NaN  ...              NaN
# ...           ...           ...        ...  ...              ...
# 1240          NaN           NaN        NaN  ...              NaN
# 1241          NaN           NaN        NaN  ...              NaN
# 1242          NaN           NaN        NaN  ...              NaN
# 1243          NaN           NaN        NaN  ...              NaN
# 1244          NaN           NaN        NaN  ...              NaN
#
#       Inoculate Date/Time  Phase  Comments  DO Control Cascade Level 3  \
# 22                    NaN    NaN       NaN                         NaN
# 23                    NaN    NaN       NaN                         NaN
# 24                    NaN    NaN       NaN                         NaN
# 25                    NaN    NaN       NaN                         NaN
# 26                    NaN    NaN       NaN                         NaN
# ...                   ...    ...       ...                         ...
# 1240                  NaN    NaN       NaN                         NaN
# 1241                  NaN    NaN       NaN                         NaN
# 1242                  NaN    NaN       NaN                         NaN
# 1243                  NaN    NaN       NaN                         NaN
# 1244                  NaN    NaN       NaN                         NaN
#
#       Feed #1 Profile  Condition  batch_end  feed_time  Timepoint (#)
# 22                NaN        NaN        NaN        NaN            S00
# 23                NaN        NaN        NaN        NaN            S01
# 24                NaN        NaN        NaN        NaN            S02
# 25                NaN        NaN        NaN        NaN            S03
# 26                NaN        NaN        NaN        NaN            S04
# ...               ...        ...        ...        ...            ...
# 1240              NaN        NaN        NaN        NaN            S01
# 1241              NaN        NaN        NaN        NaN            S02
# 1242              NaN        NaN        NaN        NaN            S03
# 1243              NaN        NaN        NaN        NaN            S04
# 1244              NaN        NaN        NaN        NaN            S05
#
# [1245 rows x 66 columns]

# %%
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Liquid_volume','Feed_volume']]
df
# Out:
#                             Parent Culture Timepoint (#)  Liquid_volume  \
# 22     DDB_PD_005_AMBR_DDB12-001_R03_Main_           S00     102.716176
# 23     DDB_PD_005_AMBR_DDB12-001_R03_Main_           S01     101.313251
# 24     DDB_PD_005_AMBR_DDB12-001_R03_Main_           S02      98.343777
# 25     DDB_PD_005_AMBR_DDB12-001_R03_Main_           S03      97.108626
# 26     DDB_PD_005_AMBR_DDB12-001_R03_Main_           S04      96.217887
# ...                                    ...           ...            ...
# 1240  DDB_PD_123_AMBR_SDT201-002_R13_Main_           S01      99.658906
# 1241  DDB_PD_123_AMBR_SDT201-002_R13_Main_           S02      91.025133
# 1242  DDB_PD_123_AMBR_SDT201-002_R13_Main_           S03      97.023156
# 1243  DDB_PD_123_AMBR_SDT201-002_R13_Main_           S04     113.200486
# 1244  DDB_PD_123_AMBR_SDT201-002_R13_Main_           S05     164.807885
#
#       Feed_volume
# 22       0.000000
# 23       0.000000
# 24       0.000000
# 25       0.000000
# 26       0.000000
# ...           ...
# 1240     0.000000
# 1241     0.000000
# 1242     6.040741
# 1243    21.747035
# 1244    61.083605
#
# [1245 rows x 4 columns]

# %%
pd.concat([offline_df,df[['Liquid_volume','Feed_volume']]],axis=1)
# Out:
#               Timepoint Sample       Experiment  \
# 0     DDB_PD_005_AMBR_R01__S00  DDB_PD_005_AMBR
# 1     DDB_PD_005_AMBR_R01__S01  DDB_PD_005_AMBR
# 2     DDB_PD_005_AMBR_R01__S02  DDB_PD_005_AMBR
# 3     DDB_PD_005_AMBR_R01__S03  DDB_PD_005_AMBR
# 4     DDB_PD_005_AMBR_R01__S04  DDB_PD_005_AMBR
# ...                        ...              ...
# 1240  DDB_PD_123_AMBR_R13__S01  DDB_PD_123_AMBR
# 1241  DDB_PD_123_AMBR_R13__S02  DDB_PD_123_AMBR
# 1242  DDB_PD_123_AMBR_R13__S03  DDB_PD_123_AMBR
# 1243  DDB_PD_123_AMBR_R13__S04  DDB_PD_123_AMBR
# 1244  DDB_PD_123_AMBR_R13__S05  DDB_PD_123_AMBR
#
#                             Parent Culture Reactor/Plate/Flask Number  \
# 0       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 1       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 2       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 3       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 4       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# ...                                    ...                        ...
# 1240  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1241  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1242  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1243  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1244  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
#
#      Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  \
# 0              S00       0.036495                 1.0    0.256
# 1              S01       3.047016                 1.0    0.628
# 2              S02       6.018670                 2.5    1.800
# 3              S03       9.016564                 1.0    5.365
# 4              S04      12.019295                 1.0   14.650
# ...            ...            ...                 ...      ...
# 1240           S01      12.035416                 7.0   13.485
# 1241           S02      16.157046                 5.0   33.240
# 1242           S03      36.227630                 5.5   80.950
# 1243           S04      56.433416                 5.5  153.450
# 1244           S05      76.199868                 7.5  276.900
#
#       D-glucose [g/L]  acetic acid [g/L]  ...  lost_mg_mg  lost_mg_cumsum_mg  \
# 0           21.867193           0.000000  ...         NaN                0.0
# 1           21.757897           0.000000  ...         NaN                0.0
# 2           20.801498           0.129068  ...         NaN                0.0
# 3           16.772116           0.362876  ...         NaN                0.0
# 4            9.421337           0.568955  ...         NaN                0.0
# ...               ...                ...  ...         ...                ...
# 1240         7.117199           0.585246  ...         NaN                0.0
# 1241         0.000000           0.000000  ...         NaN                0.0
# 1242         0.000000           0.000000  ...         NaN                0.0
# 1243         0.000000           0.000000  ...         NaN                0.0
# 1244         0.000000           0.000000  ...         NaN                0.0
#
#       lost_mn_µg  lost_mn_cumsum_µg  lost_mo_µg  lost_mo_cumsum_µg  \
# 0            NaN                0.0         NaN                0.0
# 1            NaN                0.0         NaN                0.0
# 2            NaN                0.0         NaN                0.0
# 3            NaN                0.0         NaN                0.0
# 4            NaN                0.0         NaN                0.0
# ...          ...                ...         ...                ...
# 1240         NaN                0.0         NaN                0.0
# 1241         NaN                0.0         NaN                0.0
# 1242         NaN                0.0         NaN                0.0
# 1243         NaN                0.0         NaN                0.0
# 1244         NaN                0.0         NaN                0.0
#
#       lost_zn_µg  lost_zn_cumsum_µg  Liquid_volume  Feed_volume
# 0            NaN                0.0     103.431405     0.000000
# 1            NaN                0.0     102.008286     0.000000
# 2            NaN                0.0      99.112896     0.000000
# 3            NaN                0.0      97.982498     0.000000
# 4            NaN                0.0      97.274281     0.000000
# ...          ...                ...            ...          ...
# 1240         NaN                0.0      99.658906     0.000000
# 1241         NaN                0.0      91.025133     0.000000
# 1242         NaN                0.0      97.023156     6.040741
# 1243         NaN                0.0     113.200486    21.747035
# 1244         NaN                0.0     164.807885    61.083605
#
# [1245 rows x 105 columns]

# %%
pd.merge(left=offline_df,right=df,how='inner')
# Out:
#               Timepoint Sample       Experiment  \
# 0     DDB_PD_005_AMBR_R01__S00  DDB_PD_005_AMBR
# 1     DDB_PD_005_AMBR_R01__S01  DDB_PD_005_AMBR
# 2     DDB_PD_005_AMBR_R01__S02  DDB_PD_005_AMBR
# 3     DDB_PD_005_AMBR_R01__S03  DDB_PD_005_AMBR
# 4     DDB_PD_005_AMBR_R01__S04  DDB_PD_005_AMBR
# ...                        ...              ...
# 1240  DDB_PD_123_AMBR_R13__S01  DDB_PD_123_AMBR
# 1241  DDB_PD_123_AMBR_R13__S02  DDB_PD_123_AMBR
# 1242  DDB_PD_123_AMBR_R13__S03  DDB_PD_123_AMBR
# 1243  DDB_PD_123_AMBR_R13__S04  DDB_PD_123_AMBR
# 1244  DDB_PD_123_AMBR_R13__S05  DDB_PD_123_AMBR
#
#                             Parent Culture Reactor/Plate/Flask Number  \
# 0       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 1       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 2       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 3       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 4       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# ...                                    ...                        ...
# 1240  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1241  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1242  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1243  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1244  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
#
#      Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  \
# 0              S00       0.036495                 1.0    0.256
# 1              S01       3.047016                 1.0    0.628
# 2              S02       6.018670                 2.5    1.800
# 3              S03       9.016564                 1.0    5.365
# 4              S04      12.019295                 1.0   14.650
# ...            ...            ...                 ...      ...
# 1240           S01      12.035416                 7.0   13.485
# 1241           S02      16.157046                 5.0   33.240
# 1242           S03      36.227630                 5.5   80.950
# 1243           S04      56.433416                 5.5  153.450
# 1244           S05      76.199868                 7.5  276.900
#
#       D-glucose [g/L]  acetic acid [g/L]  ...  lost_mg_mg  lost_mg_cumsum_mg  \
# 0           21.867193           0.000000  ...         NaN                0.0
# 1           21.757897           0.000000  ...         NaN                0.0
# 2           20.801498           0.129068  ...         NaN                0.0
# 3           16.772116           0.362876  ...         NaN                0.0
# 4            9.421337           0.568955  ...         NaN                0.0
# ...               ...                ...  ...         ...                ...
# 1240         7.117199           0.585246  ...         NaN                0.0
# 1241         0.000000           0.000000  ...         NaN                0.0
# 1242         0.000000           0.000000  ...         NaN                0.0
# 1243         0.000000           0.000000  ...         NaN                0.0
# 1244         0.000000           0.000000  ...         NaN                0.0
#
#       lost_mn_µg  lost_mn_cumsum_µg  lost_mo_µg  lost_mo_cumsum_µg  \
# 0            NaN                0.0         NaN                0.0
# 1            NaN                0.0         NaN                0.0
# 2            NaN                0.0         NaN                0.0
# 3            NaN                0.0         NaN                0.0
# 4            NaN                0.0         NaN                0.0
# ...          ...                ...         ...                ...
# 1240         NaN                0.0         NaN                0.0
# 1241         NaN                0.0         NaN                0.0
# 1242         NaN                0.0         NaN                0.0
# 1243         NaN                0.0         NaN                0.0
# 1244         NaN                0.0         NaN                0.0
#
#       lost_zn_µg  lost_zn_cumsum_µg  Liquid_volume  Feed_volume
# 0            NaN                0.0     103.431405     0.000000
# 1            NaN                0.0     102.008286     0.000000
# 2            NaN                0.0      99.112896     0.000000
# 3            NaN                0.0      97.982498     0.000000
# 4            NaN                0.0      97.274281     0.000000
# ...          ...                ...            ...          ...
# 1240         NaN                0.0      99.658906     0.000000
# 1241         NaN                0.0      91.025133     0.000000
# 1242         NaN                0.0      97.023156     6.040741
# 1243         NaN                0.0     113.200486    21.747035
# 1244         NaN                0.0     164.807885    61.083605
#
# [1245 rows x 105 columns]

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
# concat online with sliced dataframe
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values in liquid volume column from offline data rows with the previous liquid volume value from the online data 
df['Liquid_volume'] = df['Liquid_volume'].fillna(method='bfill')
df['Feed_volume'] = df['Feed_volume'].fillna(method='bfill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Liquid_volume','Feed_volume']]
offline_df = pd.concat([offline_df,df[['Liquid_volume','Feed_volume']]],axis=1)

# %% [markdown]
# #### Net compound formation/consumption

# %% [markdown]
# ##### Net biomass (cmol)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_cmol'
residual_col = 'CDW_avg_cmolar'
new_net_col = 'net_biomass_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net biomass (g)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_g'
residual_col = 'CDW_avg [g/L]'
new_net_col = 'net_biomass_g'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (cmol)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_cmol'
residual_col = 'glucose_cmolar'
new_net_col = 'net_glucose_cmol'
feed_conc = 500/180.156*6
init_amount = 2/180.156*6

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (g)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_g'
residual_col = 'D-glucose [g/L]'
new_net_col = 'net_glucose_g'
feed_conc = 500
init_amount = 2

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net tryptophan (cmol)

# %%
lost_cumsum_col = 'lost_tryptophan_cumsum_cmol'
residual_col = 'tryptophan_cmolar'
new_net_col = 'net_tryptophan_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net acetate (cmol)

# %%
lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
residual_col = 'acetic_acid_cmolar'
new_net_col = 'net_acetic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net citrate (cmol)

# %%
lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
residual_col = 'citric_acid_cmolar'
new_net_col = 'net_citric_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net ethanol (cmol)

# %%
lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
residual_col = 'ethanol_cmolar'
new_net_col = 'net_ethanol_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net formate (cmol)

# %%
lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
residual_col = 'formic_acid_cmolar'
new_net_col = 'net_formic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net lactate (cmol)

# %%
lost_cumsum_col = 'lost_lactate_cumsum_cmol'
residual_col = 'lactate_cmolar'
new_net_col = 'net_lactate_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net pyruvate (cmol)

# %%
lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
residual_col = 'pyruvic_acid_cmolar'
new_net_col = 'net_pyruvic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net succinate (cmol)

# %%
lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
residual_col = 'succinic_acid_cmolar'
new_net_col = 'net_succinic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net metal

# %%
def net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col):
    offline_df[new_net_col] = -offline_df[residual_col]*offline_df['Liquid_volume']/1000 - offline_df[lost_cumsum_col] + offline_df[init_conc_col]*0.1 + offline_df[feed_conc_col]*offline_df['Feed_volume']/1000

# %%
medium_data = pd.read_excel("../../../data/trace_metal_medium_data/trace_metal_medium_data.xlsx")
medium_data.head()
# Out:
#                         Parent Culture  batch co [µg/L]  batch cu [µg/L]  \
# 0  DDB_PD_036_AMBR_DDB35-001_R14_Main_       118.739693       102.125235
# 1  DDB_PD_036_AMBR_DDB35-001_R17_Main_       118.739693       102.125235
# 2  DDB_PD_036_AMBR_DDB35-001_R18_Main_       118.739693       102.125235
# 3  DDB_PD_036_AMBR_DDB35-001_R21_Main_       118.739693       102.125235
# 4  DDB_PD_036_AMBR_DDB35-001_R22_Main_       118.739693       102.125235
#
#    batch fe [µg/L]  batch mg [mg/L]  batch mn [µg/L]  batch mo [µg/L]  \
# 0      5245.140982        55.740569        96.232579       100.391646
# 1      5245.140982        55.740569        96.232579       100.391646
# 2      5245.140982        55.740569        96.232579       100.391646
# 3      5245.140982        55.740569        96.232579       100.391646
# 4      5245.140982        55.740569        96.232579       100.391646
#
#    batch zn [µg/L]  feed co [µg/L]  feed cu [µg/L]  feed fe [µg/L]  \
# 0       145.411919      285.956449      261.921688    17695.277036
# 1       145.411919      285.956449      261.921688    17695.277036
# 2       145.411919      285.956449      261.921688    17695.277036
# 3       145.411919      285.956449      261.921688    17695.277036
# 4       145.411919      285.956449      261.921688    17695.277036
#
#    feed mg [mg/L]  feed mn [µg/L]  feed mo [µg/L]  feed zn [µg/L]
# 0     1403.622948       221.45028      339.797078      309.756171
# 1     1403.622948       221.45028      339.797078      309.756171
# 2     1403.622948       221.45028      339.797078      309.756171
# 3     1403.622948       221.45028      339.797078      309.756171
# 4     1403.622948       221.45028      339.797078      309.756171

# %%
offline_df = pd.merge(left=offline_df, right=medium_data, how="left")
offline_df.head()
# Out:
#            Timepoint Sample       Experiment  \
# 0  DDB_PD_005_AMBR_R01__S00  DDB_PD_005_AMBR
# 1  DDB_PD_005_AMBR_R01__S01  DDB_PD_005_AMBR
# 2  DDB_PD_005_AMBR_R01__S02  DDB_PD_005_AMBR
# 3  DDB_PD_005_AMBR_R01__S03  DDB_PD_005_AMBR
# 4  DDB_PD_005_AMBR_R01__S04  DDB_PD_005_AMBR
#
#                        Parent Culture Reactor/Plate/Flask Number  \
# 0  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 1  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 2  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 3  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 4  DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
#
#   Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD  D-glucose [g/L]  \
# 0           S00       0.036495                 1.0   0.256        21.867193
# 1           S01       3.047016                 1.0   0.628        21.757897
# 2           S02       6.018670                 2.5   1.800        20.801498
# 3           S03       9.016564                 1.0   5.365        16.772116
# 4           S04      12.019295                 1.0  14.650         9.421337
#
#    acetic acid [g/L]  ...  batch mn [µg/L]  batch mo [µg/L]  batch zn [µg/L]  \
# 0           0.000000  ...              NaN              NaN              NaN
# 1           0.000000  ...              NaN              NaN              NaN
# 2           0.129068  ...              NaN              NaN              NaN
# 3           0.362876  ...              NaN              NaN              NaN
# 4           0.568955  ...              NaN              NaN              NaN
#
#    feed co [µg/L]  feed cu [µg/L]  feed fe [µg/L]  feed mg [mg/L]  \
# 0             NaN             NaN             NaN             NaN
# 1             NaN             NaN             NaN             NaN
# 2             NaN             NaN             NaN             NaN
# 3             NaN             NaN             NaN             NaN
# 4             NaN             NaN             NaN             NaN
#
#    feed mn [µg/L]  feed mo [µg/L]  feed zn [µg/L]
# 0             NaN             NaN             NaN
# 1             NaN             NaN             NaN
# 2             NaN             NaN             NaN
# 3             NaN             NaN             NaN
# 4             NaN             NaN             NaN
#
# [5 rows x 131 columns]

# %%
lost_cumsum_col = 'lost_co_cumsum_µg'
residual_col = 'co [µg/L]'
new_net_col = 'net_co_µg'
feed_conc_col = "feed co [µg/L]"
init_conc_col = "batch co [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_cu_cumsum_µg'
residual_col = 'cu [µg/L]'
new_net_col = 'net_cu_µg'
feed_conc_col = "feed cu [µg/L]"
init_conc_col = "batch cu [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_fe_cumsum_µg'
residual_col = 'fe [µg/L]'
new_net_col = 'net_fe_µg'
feed_conc_col = "feed fe [µg/L]"
init_conc_col = "batch fe [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_mg_cumsum_mg'
residual_col = 'mg [mg/L]'
new_net_col = 'net_mg_mg'
feed_conc_col = "feed mg [mg/L]"
init_conc_col = "batch mg [mg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_mn_cumsum_µg'
residual_col = 'mn [µg/L]'
new_net_col = 'net_mn_µg'
feed_conc_col = "feed mn [µg/L]"
init_conc_col = "batch mn [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_mo_cumsum_µg'
residual_col = 'mo [µg/L]'
new_net_col = 'net_mo_µg'
feed_conc_col = "feed mo [µg/L]"
init_conc_col = "batch mo [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

lost_cumsum_col = 'lost_zn_cumsum_µg'
residual_col = 'zn [µg/L]'
new_net_col = 'net_zn_µg'
feed_conc_col = "feed zn [µg/L]"
init_conc_col = "batch zn [µg/L]"
net_metal_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc_col, init_conc_col)

# %% [markdown]
# #### CTR_int, Base volume, and OTR_int from online data into offline data

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values with previous value
df['Formed_CO2'] = df['Formed_CO2'].fillna(method='bfill')
df['Consumed_O2'] = df['Consumed_O2'].fillna(method='bfill')
df['Base_volume'] = df['Base_volume'].fillna(method='bfill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Formed_CO2','Consumed_O2','Base_volume']]
offline_df = pd.concat([offline_df,df[['Formed_CO2','Consumed_O2','Base_volume']]],axis=1)

# %%
offline_df
# Out:
#               Timepoint Sample       Experiment  \
# 0     DDB_PD_005_AMBR_R01__S00  DDB_PD_005_AMBR
# 1     DDB_PD_005_AMBR_R01__S01  DDB_PD_005_AMBR
# 2     DDB_PD_005_AMBR_R01__S02  DDB_PD_005_AMBR
# 3     DDB_PD_005_AMBR_R01__S03  DDB_PD_005_AMBR
# 4     DDB_PD_005_AMBR_R01__S04  DDB_PD_005_AMBR
# ...                        ...              ...
# 1240  DDB_PD_123_AMBR_R13__S01  DDB_PD_123_AMBR
# 1241  DDB_PD_123_AMBR_R13__S02  DDB_PD_123_AMBR
# 1242  DDB_PD_123_AMBR_R13__S03  DDB_PD_123_AMBR
# 1243  DDB_PD_123_AMBR_R13__S04  DDB_PD_123_AMBR
# 1244  DDB_PD_123_AMBR_R13__S05  DDB_PD_123_AMBR
#
#                             Parent Culture Reactor/Plate/Flask Number  \
# 0       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 1       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 2       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 3       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# 4       DDB_PD_005_AMBR_DDB7-002_R01_Main_                        R01
# ...                                    ...                        ...
# 1240  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1241  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1242  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1243  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
# 1244  DDB_PD_123_AMBR_SDT201-002_R13_Main_                        R13
#
#      Timepoint (#)  Timepoint (h)  Sample volume (mL)       OD  \
# 0              S00       0.036495                 1.0    0.256
# 1              S01       3.047016                 1.0    0.628
# 2              S02       6.018670                 2.5    1.800
# 3              S03       9.016564                 1.0    5.365
# 4              S04      12.019295                 1.0   14.650
# ...            ...            ...                 ...      ...
# 1240           S01      12.035416                 7.0   13.485
# 1241           S02      16.157046                 5.0   33.240
# 1242           S03      36.227630                 5.5   80.950
# 1243           S04      56.433416                 5.5  153.450
# 1244           S05      76.199868                 7.5  276.900
#
#       D-glucose [g/L]  acetic acid [g/L]  ...  net_co_µg  net_cu_µg  \
# 0           21.867193           0.000000  ...        NaN        NaN
# 1           21.757897           0.000000  ...        NaN        NaN
# 2           20.801498           0.129068  ...        NaN        NaN
# 3           16.772116           0.362876  ...        NaN        NaN
# 4            9.421337           0.568955  ...        NaN        NaN
# ...               ...                ...  ...        ...        ...
# 1240         7.117199           0.585246  ...        NaN        NaN
# 1241         0.000000           0.000000  ...        NaN        NaN
# 1242         0.000000           0.000000  ...        NaN        NaN
# 1243         0.000000           0.000000  ...        NaN        NaN
# 1244         0.000000           0.000000  ...        NaN        NaN
#
#       net_fe_µg  net_mg_mg  net_mn_µg  net_mo_µg  net_zn_µg    Formed_CO2  \
# 0           NaN        NaN        NaN        NaN        NaN  3.860000e-07
# 1           NaN        NaN        NaN        NaN        NaN  7.690000e-05
# 2           NaN        NaN        NaN        NaN        NaN  5.069470e-04
# 3           NaN        NaN        NaN        NaN        NaN  2.318354e-03
# 4           NaN        NaN        NaN        NaN        NaN  8.204897e-03
# ...         ...        ...        ...        ...        ...           ...
# 1240        NaN        NaN        NaN        NaN        NaN  5.495703e-03
# 1241        NaN        NaN        NaN        NaN        NaN  1.910183e-02
# 1242        NaN        NaN        NaN        NaN        NaN  6.225259e-02
# 1243        NaN        NaN        NaN        NaN        NaN  1.838308e-01
# 1244        NaN        NaN        NaN        NaN        NaN  5.038444e-01
#
#        Consumed_O2  Base_volume
# 0     3.570000e-07     2.685577
# 1     2.003640e-04     2.685577
# 2     9.529460e-04     2.712126
# 3     2.981309e-03     3.025313
# 4     8.133920e-03     3.839590
# ...            ...          ...
# 1240  6.858616e-03     1.422721
# 1241  2.197235e-02     3.527416
# 1242  6.999271e-02     6.122353
# 1243  1.943044e-01    14.491154
# 1244  5.123902e-01    34.618648
#
# [1245 rows x 141 columns]

# %% [markdown]
# ## Export data

# %%
# online_df.iloc[::5].to_excel('../../../_data/exponential_fed-batch_scale-down_online_data.xlsx',index=False)
online_df.to_excel('../../../data/processed_fermentation_data/processed_online_data.xlsx',index=False)

# %%
offline_df.to_excel('../../../data/processed_fermentation_data/processed_offline_data.xlsx',index=False)

# %%
meta_df.to_excel('../../../data/processed_fermentation_data/processed_meta_data.xlsx',index=False)
